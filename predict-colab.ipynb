# %%
from tensorflow.keras.models import load_model
from tensorflow.keras.preprocessing.image import load_img, img_to_array
import numpy as np
from sklearn.preprocessing import LabelEncoder

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
model_save_path = '/content/drive/MyDrive/Do an chuyen nganh/skin_disease_cnn_model_newv2.keras'
class_names = ['akiec', 'bcc', 'bkl', 'df', 'mel', 'nv', 'vasc']
# Tải lại mô hình đã lưu
cnn_model = load_model(model_save_path)

# %%
new_image_path = '/content/drive/MyDrive/Do an chuyen nganh/data3/test/vasc/ISIC_0025452.jpg'
img_width, img_height = 192, 192


def load_and_preprocess_image(img_path, img_width, img_height):
    img = load_img(img_path, target_size=(img_width, img_height))
    img_array = img_to_array(img)
    img_array = np.expand_dims(img_array, axis=0)
    return img_array

image_array = load_and_preprocess_image(new_image_path, img_width, img_height)
predictions = cnn_model.predict(image_array)

predicted_class = np.argmax(predictions[0])
print(predictions)
print(predicted_class)
predicted_label = class_names[predicted_class]
print(f'Dự đoán bệnh: {predicted_label}')
# Out:
# 1/1 [==============================] - 0s 254ms/step
# [[6.7957985e-32 4.3393676e-28 9.8136581e-23 8.1749492e-37 8.0676040e-22
#   3.8272496e-14 1.0000000e+00]]
# 6
# Dự đoán bệnh: vasc
